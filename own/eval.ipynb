# %%
import numpy as np
import eval
from importlib import reload
reload(eval)
# Out:
# <module 'eval' from 'c:\\Users\\wojci\\Desktop\\UCL 4th\\B 3D\\final_project\\normals_HoughCNN\\own\\eval.py'>

# %%
gt = eval.load_xyz('inputs/rect_small.xyz')
pr = eval.load_xyz('outputs/rect_small_better_normals.xyz')
eval.evaluate_normals(gt, pr)

# %%
[str(int(tick)) for tick in np.arange(0, 20 + 1, 20 / 5)]
# Out:
# ['0', '4', '8', '12', '16', '20']
